# %% [markdown]
# ### Execute the cell below before proceeding.
#
# The code in this cell will download a file with a Python script from the Internet. Make sure that you have a network connection before executing it.

# %%
# %matplotlib widget
import requests
#with open("strang_house.py", 'w') as foo:
#    foo.write(requests.get("https://git.io/fjdTp").text)
from strang_house import *

# %% [markdown]
# # Strang house

# %% [markdown]
# Strang house is a program illustrating the effect of linear transformations. Drag the red and blue dots to deform the drawing of a house according to a linear transformation. The matrix of the resulting transformation is  displayed in the upper left corner. The pale drawing is the original image of the house, before the transformation.

# %%
strang_house()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

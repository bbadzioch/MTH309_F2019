# %% [markdown]
# # Matrix Transformations
#
# This notebook illustrates the effect of a linear transformation $T_A\colon {\mathbb R}^2 \to {\mathbb R}^2$ given by $T_A({\mathbf v}) = A{\mathbf v}$, where $A$ is a 2$\times$2 matrix.

# %% [markdown]
# First, execute the cell below.
#
# **Note:** The code in this cell will download a file with a Python script from the Internet, so make sure that you have a network connection before you execute it.

# %%
import requests
with open("matrix_t.py", 'w') as foo:
    foo.write(requests.get("https://git.io/fj5ez").text)
from matrix_t import *

# %% [markdown]
# Enter a 2$\times$2 matrix $A$:

# %%
A = Matrix([[-1, 1], [2, 3]])
A
# Out:
# ⎡-1  1⎤
# ⎢     ⎥
# ⎣2   3⎦

# %% [markdown]
# The next cell produces a picture demonstrating the effect of the linear transformation $T_A$. You can use controls above the picture to pan and zoom on it.

# %%
matrix_t(A)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1501">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="ddbf6e0f-cbf1-4b9c-b3a5-be351f9da3cb"></div>

# %%
import requests
with open("matrix_t1.py", 'w') as foo:
    foo.write(requests.get("https://git.io/fj5ez").text)
from matrix_t1 import *

# %%
A = Matrix([[-1, 1], [2, 2]])
A
# Out:
# ⎡-1  1⎤
# ⎢     ⎥
# ⎣2   2⎦

# %%
matrix_t(A)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="abe84890-3819-49f1-a6a9-c04d2a0e5acf"></div>

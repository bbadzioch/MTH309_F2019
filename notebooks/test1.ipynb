# %%
import requests
s = "https://raw.githubusercontent.com/bbadzioch/MTH309_F2019/master/notebooks/matrix_t.py"
t = requests.get(s).text
with open("matrix_t1.py", 'w') as foo:
    foo.write(t)
from matrix_t1 import *

# %%
A = Matrix([[-1, 1], [2, 2]])
A
# Out:
# ⎡-1  1⎤
# ⎢     ⎥
# ⎣2   2⎦

# %%
matrix_t(A)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1501">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="e282b9a3-ec05-4dbb-ab67-269bce271a7d"></div>

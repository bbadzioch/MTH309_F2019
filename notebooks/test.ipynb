# %%
from matrix_t import *
from math import *

# %%
matrix_t([[1, 1], [1, 0]])
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="06931dc1-0391-4247-8275-377b914aeba1"></div>

# %%
animated_house(delay = 40)
plt.show()

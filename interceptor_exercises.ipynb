# %% [markdown]
#  ### <span style="color:red">**Enter your name and person number here:**</span>
#
#  # John Smith 5019-1234

# %% [markdown]
# ### <span style="color:red">**Execute the cell below before proceeding:**</span>

# %%
#from resources309 import *
#get_resources("interceptor.py")

# %matplotlib notebook
from py309.interceptor import *
from sympy import *
init_printing(use_latex='mathjax')
# Out:
# Resource check finished.

# %% [markdown]
# # Interceptor

# %% [markdown]
# Interceptor is a simple game. You are given the position and the velocity vector of a target. Your objective is to shoot it down. You are equipped with a single missile located at the position $[0, 0]$. The missile fires straight up, with the velocity vector $[0, 4]$. You need to select the time when the missile must be launched in order to intercept the target. The launch time is always an integer. If the time you select is correct, the target will get destroyed.
#
# **Exercise (20 points):** Destroy the target. Once you do it, a screen saying "TARGET INTERCEPTED" will be displayed. At this point save the notebook, and upload this notebook file to UBLearns.
#
# **Note:** Prior to saving this notebooks press the power button above the game window: <img src="https://raw.githubusercontent.com/bbadzioch/MTH309_F2018/master/supplements/power_button.png" style="width:30pt;"> Otherwise the notebook may not get saved properly to show that you completed this assignment.

# %% [markdown]
# Execute the next cell to start the game:

# %%
x=interceptor()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
A = Matrix([[4, 0, 60], [1, -4, -25]])
A
# Out:
# ⎡4  0   60 ⎤
# ⎢          ⎥
# ⎣1  -4  -25⎦

# %%
A.rref()
# Out:
# ⎛⎡1  0  15⎤        ⎞
# ⎜⎢        ⎥, (0, 1)⎟
# ⎝⎣0  1  10⎦        ⎠

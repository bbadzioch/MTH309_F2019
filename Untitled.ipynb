# %%
# %matplotlib notebook
from importlib import reload
import orientation as r
reload(r)

r.strang_house()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
x = [1, 2, 3]

f = lambda : len(x)

# %%
import numpy as np
operator
# Out:
# 3

# %%
import operator
f = operator.attrgetter("lines.Line2D")
import matplotlib 

f(matplotlib)
# Out:
# matplotlib.lines.Line2D

# %%
z, = plt.plot([1, 2], [3, 4])

# %%
type(z)
# Out:
# matplotlib.lines.Line2D

# %%
dir(z)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_agg_filter',
#  '_alias_map',
#  '_alpha',
#  '_animated',
#  '_antialiased',
#  '_axes',
#  '_clipon',
#  '_clippath',
#  '_color',
#  '_contains',
#  '_dashOffset',
#  '_dashSeq',
#  '_dashcapstyle',
#  '_dashjoinstyle',
#  '_drawStyles_l',
#  '_drawStyles_s',
#  '_drawstyle',
#  '_get_clipping_extent_bbox',
#  '_get_markerfacecolor',
#  '_get_transformed_path',
#  '_gid',
#  '_in_layout',
#  '_invalidx',
#  '_invalidy',
#  '_is_sorted',
#  '_label',
#  '_lineStyles',
#  '_linestyle',
#  '_linestyles',
#  '_linewidth',
#  '_marker',
# ...

# %%
repr(z.__class__)
# Out:
# "<class 'matplotlib.lines.Line2D'>"

# %%
dir(z)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_agg_filter',
#  '_alias_map',
#  '_alpha',
#  '_animated',
#  '_antialiased',
#  '_axes',
#  '_clipon',
#  '_clippath',
#  '_color',
#  '_contains',
#  '_dashOffset',
#  '_dashSeq',
#  '_dashcapstyle',
#  '_dashjoinstyle',
#  '_drawStyles_l',
#  '_drawStyles_s',
#  '_drawstyle',
#  '_get_clipping_extent_bbox',
#  '_get_markerfacecolor',
#  '_get_transformed_path',
#  '_gid',
#  '_in_layout',
#  '_invalidx',
#  '_invalidy',
#  '_is_sorted',
#  '_label',
#  '_lineStyles',
#  '_linestyle',
#  '_linestyles',
#  '_linewidth',
#  '_marker',
# ...

# %%
z
